# %% [markdown]
# <a href="https://colab.research.google.com/github/bbishal12/Quiz0/blob/main/Twitter_Quiz11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Visualization
# ##Bishal Budhathoki
# ##Quiz 11: Twitter

# %% [markdown]
# Using either the math_cs credentials or your own;
#
# Get authenticated to twitter.
# Find the top trending 10 topics in the world and display them by name
# Search for your favorite show, actor, sports team or player and see what twitter is saying about them.

# %% [markdown]
# First of all, I am going to install twitter api to get all the data straignt from twitter. pip install twitter does the installation of library in my system.

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.19.3-py2.py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 3.8 MB/s
# Installing collected packages: twitter
# Successfully installed twitter-1.19.3

# %% [markdown]
# The following code authenticated our library with twitter api. For now I am using the secret file form Dr. Jacob our instructor which I have saved in google colab as .py file

# %%
import twitter
import config

CONSUMER_KEY = config.CONSUMER_KEY
CONSUMER_SECRET = config.CONSUMER_SECRET
OAUTH_TOKEN = config.OAUTH_TOKEN
OAUTH_TOKEN_SECRET = config.OAUTH_TOKEN_SECRET
auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

mathcs_twitter_api = twitter.Twitter(auth=auth)

# %% [markdown]
# To find out the top 10 trends in the twitter world I am going to run the following command.

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = mathcs_twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = mathcs_twitter_api.trends.place(_id=US_WOE_ID)

for i in range(10):
    print(world_trends[0]['trends'][i]['query'])
# Out:
# Bruna
# B%C3%A1rbara
# %23jogodadiscordia
# %22O+Arthur%22
# %23TheBachelor
# %23WWERaw
# %22Arthur+Aguiar%22
# Juliette
# Donovan
# VERNON

# %% [markdown]
# The another way to print out the data is by using json package. JSON is an alternative to store data which is why it is used in no-sql databases.

# %%
import json

print(json.dumps(world_trends, indent=1))
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "Bruna",
#     "url": "http://twitter.com/search?q=Bruna",
#     "promoted_content": null,
#     "query": "Bruna",
#     "tweet_volume": 43376
#    },
#    {
#     "name": "B\u00e1rbara",
#     "url": "http://twitter.com/search?q=B%C3%A1rbara",
#     "promoted_content": null,
#     "query": "B%C3%A1rbara",
#     "tweet_volume": 160309
#    },
#    {
#     "name": "#jogodadiscordia",
#     "url": "http://twitter.com/search?q=%23jogodadiscordia",
#     "promoted_content": null,
#     "query": "%23jogodadiscordia",
#     "tweet_volume": 16730
#    },
#    {
#     "name": "O Arthur",
#     "url": "http://twitter.com/search?q=%22O+Arthur%22",
#     "promoted_content": null,
#     "query": "%22O+Arthur%22",
#     "tweet_volume": 537382
#    },
#    {
#     "name": "#TheBachelor",
#     "url": "http://twitter.com/search?q=%23TheBachelor",
#     "promoted_content": null,
#     "query": "%23TheBachelor",
#     "tweet_volume": 15130
#    },
#    {
#     "name": "#WWERaw",
#     "url": "http://twitter.com/search?q=%23WWERaw",
#     "promoted_content": null,
#     "query": "%23WWERaw",
#     "tweet_volume": 30006
#    },
#    {
#     "name": "Arthur Aguiar",
#     "url": "http://twitter.com/search?q=%22Arthur+Aguiar%22",
#     "promoted_content": null,
#     "query": "%22Arthur+Aguiar%22",
#     "tweet_volume": 70593
#    },
#    {
#     "name": "Juliette",
#     "url": "http://twitter.com/search?q=Juliette",
#     "promoted_content": null,
#     "query": "Juliette",
#     "tweet_volume": 60099
#    },
#    {
#     "name": "Donovan",
#     "url": "http://twitter.com/search?q=Donovan",
#     "promoted_content": null,
#     "query": "Donovan",
#     "tweet_volume": 27227
#    },
#    {
#     "name": "VERNON",
#     "url": "http://twitter.com/search?q=VERNON",
#     "promoted_content": null,
#     "query": "VERNON",
#     "tweet_volume": 49174
#    },
#    {
#     "name": "Duke",
#     "url": "http://twitter.com/search?q=Duke",
#     "promoted_content": null,
#     "query": "Duke",
#     "tweet_volume": 41285
#    },
#    {
#     "name": "Artur",
#     "url": "http://twitter.com/search?q=Artur",
#     "promoted_content": null,
#     "query": "Artur",
#     "tweet_volume": 20262
#    },
#    {
#     "name": "#GeriD\u00f6nd\u00fc",
#     "url": "http://twitter.com/search?q=%23GeriD%C3%B6nd%C3%BC",
#     "promoted_content": null,
#     "query": "%23GeriD%C3%B6nd%C3%BC",
#     "tweet_volume": null
#    },
#    {
#     "name": "Lucas",
#     "url": "http://twitter.com/search?q=Lucas",
#     "promoted_content": null,
#     "query": "Lucas",
#     "tweet_volume": 265719
#    },
#    {
#     "name": "Shanae",
#     "url": "http://twitter.com/search?q=Shanae",
#     "promoted_content": null,
#     "query": "Shanae",
#     "tweet_volume": null
#    },
#    {
#     "name": "Essa Maria",
#     "url": "http://twitter.com/search?q=%22Essa+Maria%22",
#     "promoted_content": null,
#     "query": "%22Essa+Maria%22",
#     "tweet_volume": 13008
#    },
#    {
#     "name": "Clayton",
#     "url": "http://twitter.com/search?q=Clayton",
#     "promoted_content": null,
#     "query": "Clayton",
#     "tweet_volume": 10144
#    },
#    {
#     "name": "tuty",
#     "url": "http://twitter.com/search?q=tuty",
#     "promoted_content": null,
#     "query": "tuty",
#     "tweet_volume": 11439
#    },
#    {
#     "name": "Essa Jessi",
#     "url": "http://twitter.com/search?q=%22Essa+Jessi%22",
#     "promoted_content": null,
#     "query": "%22Essa+Jessi%22",
#     "tweet_volume": 11858
#    },
#    {
#     "name": "#MasterChefArgentina",
#     "url": "http://twitter.com/search?q=%23MasterChefArgentina",
#     "promoted_content": null,
#     "query": "%23MasterChefArgentina",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kurt Zouma",
#     "url": "http://twitter.com/search?q=%22Kurt+Zouma%22",
#     "promoted_content": null,
#     "query": "%22Kurt+Zouma%22",
#     "tweet_volume": 29107
#    },
#    {
#     "name": "Matheus Nascimento",
#     "url": "http://twitter.com/search?q=%22Matheus+Nascimento%22",
#     "promoted_content": null,
#     "query": "%22Matheus+Nascimento%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Virginia",
#     "url": "http://twitter.com/search?q=Virginia",
#     "promoted_content": null,
#     "query": "Virginia",
#     "tweet_volume": 57752
#    },
#    {
#     "name": "\u30dc\u30fc\u30e4\u30f3",
#     "url": "http://twitter.com/search?q=%E3%83%9C%E3%83%BC%E3%83%A4%E3%83%B3",
#     "promoted_content": null,
#     "query": "%E3%83%9C%E3%83%BC%E3%83%A4%E3%83%B3",
#     "tweet_volume": null
#    },
#    {
#     "name": "\uc774\uc2dc\ud615 \uc120\uc218",
#     "url": "http://twitter.com/search?q=%22%EC%9D%B4%EC%8B%9C%ED%98%95+%EC%84%A0%EC%88%98%22",
#     "promoted_content": null,
#     "query": "%22%EC%9D%B4%EC%8B%9C%ED%98%95+%EC%84%A0%EC%88%98%22",
#     "tweet_volume": 17155
#    },
#    {
#     "name": "Bad Nat",
#     "url": "http://twitter.com/search?q=%22Bad+Nat%22",
#     "promoted_content": null,
#     "query": "%22Bad+Nat%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Planta",
#     "url": "http://twitter.com/search?q=Planta",
#     "promoted_content": null,
#     "query": "Planta",
#     "tweet_volume": 66791
#    },
#    {
#     "name": "Arthur maceta",
#     "url": "http://twitter.com/search?q=%22Arthur+maceta%22",
#     "promoted_content": null,
#     "query": "%22Arthur+maceta%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Belgrano",
#     "url": "http://twitter.com/search?q=Belgrano",
#     "promoted_content": null,
#     "query": "Belgrano",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jade Piton",
#     "url": "http://twitter.com/search?q=%22Jade+Piton%22",
#     "promoted_content": null,
#     "query": "%22Jade+Piton%22",
#     "tweet_volume": 16520
#    },
#    {
#     "name": "Shanna",
#     "url": "http://twitter.com/search?q=Shanna",
#     "promoted_content": null,
#     "query": "Shanna",
#     "tweet_volume": null
#    },
#    {
#     "name": "QUEIMA QUENGARAL",
#     "url": "http://twitter.com/search?q=%22QUEIMA+QUENGARAL%22",
#     "promoted_content": null,
#     "query": "%22QUEIMA+QUENGARAL%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Yuzuru",
#     "url": "http://twitter.com/search?q=Yuzuru",
#     "promoted_content": null,
#     "query": "Yuzuru",
#     "tweet_volume": 53231
#    },
#    {
#     "name": "Duas Caras",
#     "url": "http://twitter.com/search?q=%22Duas+Caras%22",
#     "promoted_content": null,
#     "query": "%22Duas+Caras%22",
#     "tweet_volume": 18900
#    },
#    {
#     "name": "Vai Arthur",
#     "url": "http://twitter.com/search?q=%22Vai+Arthur%22",
#     "promoted_content": null,
#     "query": "%22Vai+Arthur%22",
#     "tweet_volume": 124941
#    },
#    {
#     "name": "Dennis Allen",
#     "url": "http://twitter.com/search?q=%22Dennis+Allen%22",
#     "promoted_content": null,
#     "query": "%22Dennis+Allen%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "\uae30\uc790\ud68c\uacac",
#     "url": "http://twitter.com/search?q=%EA%B8%B0%EC%9E%90%ED%9A%8C%EA%B2%AC",
#     "promoted_content": null,
#     "query": "%EA%B8%B0%EC%9E%90%ED%9A%8C%EA%B2%AC",
#     "tweet_volume": 27571
#    },
#    {
#     "name": "\ub370\uc2a4\ub178\ud2b8",
#     "url": "http://twitter.com/search?q=%EB%8D%B0%EC%8A%A4%EB%85%B8%ED%8A%B8",
#     "promoted_content": null,
#     "query": "%EB%8D%B0%EC%8A%A4%EB%85%B8%ED%8A%B8",
#     "tweet_volume": 14486
#    },
#    {
#     "name": "RELA\u00c7\u00d5ES",
#     "url": "http://twitter.com/search?q=RELA%C3%87%C3%95ES",
#     "promoted_content": null,
#     "query": "RELA%C3%87%C3%95ES",
#     "tweet_volume": 18659
#    },
#    {
#     "name": "Nicola",
#     "url": "http://twitter.com/search?q=Nicola",
#     "promoted_content": null,
#     "query": "Nicola",
#     "tweet_volume": 16364
#    },
#    {
#     "name": "OFF\u30d1\u30c3\u30af",
#     "url": "http://twitter.com/search?q=OFF%E3%83%91%E3%83%83%E3%82%AF",
#     "promoted_content": null,
#     "query": "OFF%E3%83%91%E3%83%83%E3%82%AF",
#     "tweet_volume": null
#    },
#    {
#     "name": "Reece Beekman",
#     "url": "http://twitter.com/search?q=%22Reece+Beekman%22",
#     "promoted_content": null,
#     "query": "%22Reece+Beekman%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Faz o M",
#     "url": "http://twitter.com/search?q=%22Faz+o+M%22",
#     "promoted_content": null,
#     "query": "%22Faz+o+M%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Solusi Zaman Now",
#     "url": "http://twitter.com/search?q=%22Solusi+Zaman+Now%22",
#     "promoted_content": null,
#     "query": "%22Solusi+Zaman+Now%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u6295\u7a3f\u306e\u4e2d",
#     "url": "http://twitter.com/search?q=%E6%8A%95%E7%A8%BF%E3%81%AE%E4%B8%AD",
#     "promoted_content": null,
#     "query": "%E6%8A%95%E7%A8%BF%E3%81%AE%E4%B8%AD",
#     "tweet_volume": 156451
#    },
#    {
#     "name": "tutu",
#     "url": "http://twitter.com/search?q=tutu",
#     "promoted_content": null,
#     "query": "tutu",
#     "tweet_volume": null
#    },
#    {
#     "name": "Essa Jade",
#     "url": "http://twitter.com/search?q=%22Essa+Jade%22",
#     "promoted_content": null,
#     "query": "%22Essa+Jade%22",
#     "tweet_volume": 57890
#    },
#    {
#     "name": "Chad Gable",
#     "url": "http://twitter.com/search?q=%22Chad+Gable%22",
#     "promoted_content": null,
#     "query": "%22Chad+Gable%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hoos",
#     "url": "http://twitter.com/search?q=Hoos",
#     "promoted_content": null,
#     "query": "Hoos",
#     "tweet_volume": null
#    },
#    {
#     "name": "Vai Nat\u00e1lia",
#     "url": "http://twitter.com/search?q=%22Vai+Nat%C3%A1lia%22",
#     "promoted_content": null,
#     "query": "%22Vai+Nat%C3%A1lia%22",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2022-02-08T02:41:45Z",
#   "created_at": "2022-02-06T13:54:03Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
# [
#  {
#   "trends": [
#    {
#     "name": "#TheBachelor",
#     "url": "http://twitter.com/search?q=%23TheBachelor",
#     "promoted_content": null,
#     "query": "%23TheBachelor",
#     "tweet_volume": 15130
#    },
#    {
#     "name": "#WWERaw",
#     "url": "http://twitter.com/search?q=%23WWERaw",
#     "promoted_content": null,
#     "query": "%23WWERaw",
#     "tweet_volume": 30104
#    },
#    {
#     "name": "Duke",
#     "url": "http://twitter.com/search?q=Duke",
#     "promoted_content": null,
#     "query": "Duke",
#     "tweet_volume": 41285
#    },
#    {
#     "name": "Shanae",
#     "url": "http://twitter.com/search?q=Shanae",
#     "promoted_content": null,
#     "query": "Shanae",
#     "tweet_volume": null
#    },
#    {
#     "name": "Clayton",
#     "url": "http://twitter.com/search?q=Clayton",
#     "promoted_content": null,
#     "query": "Clayton",
#     "tweet_volume": 10144
#    },
#    {
#     "name": "Virginia",
#     "url": "http://twitter.com/search?q=Virginia",
#     "promoted_content": null,
#     "query": "Virginia",
#     "tweet_volume": 57752
#    },
#    {
#     "name": "VERNON",
#     "url": "http://twitter.com/search?q=VERNON",
#     "promoted_content": null,
#     "query": "VERNON",
#     "tweet_volume": 49174
#    },
#    {
#     "name": "#911LoneStar",
#     "url": "http://twitter.com/search?q=%23911LoneStar",
#     "promoted_content": null,
#     "query": "%23911LoneStar",
#     "tweet_volume": 11272
#    },
#    {
#     "name": "#BelowDeck",
#     "url": "http://twitter.com/search?q=%23BelowDeck",
#     "promoted_content": null,
#     "query": "%23BelowDeck",
#     "tweet_volume": null
#    },
#    {
#     "name": "Shanna",
#     "url": "http://twitter.com/search?q=Shanna",
#     "promoted_content": null,
#     "query": "Shanna",
#     "tweet_volume": null
#    },
#    {
#     "name": "Reece Beekman",
#     "url": "http://twitter.com/search?q=%22Reece+Beekman%22",
#     "promoted_content": null,
#     "query": "%22Reece+Beekman%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Dennis Allen",
#     "url": "http://twitter.com/search?q=%22Dennis+Allen%22",
#     "promoted_content": null,
#     "query": "%22Dennis+Allen%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hoos",
#     "url": "http://twitter.com/search?q=Hoos",
#     "promoted_content": null,
#     "query": "Hoos",
#     "tweet_volume": null
#    },
#    {
#     "name": "#OlympicGames",
#     "url": "http://twitter.com/search?q=%23OlympicGames",
#     "promoted_content": null,
#     "query": "%23OlympicGames",
#     "tweet_volume": 15174
#    },
#    {
#     "name": "Maryse",
#     "url": "http://twitter.com/search?q=Maryse",
#     "promoted_content": null,
#     "query": "Maryse",
#     "tweet_volume": null
#    },
#    {
#     "name": "Chad Gable",
#     "url": "http://twitter.com/search?q=%22Chad+Gable%22",
#     "promoted_content": null,
#     "query": "%22Chad+Gable%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tony Bennett",
#     "url": "http://twitter.com/search?q=%22Tony+Bennett%22",
#     "promoted_content": null,
#     "query": "%22Tony+Bennett%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Donovan",
#     "url": "http://twitter.com/search?q=Donovan",
#     "promoted_content": null,
#     "query": "Donovan",
#     "tweet_volume": 27227
#    },
#    {
#     "name": "Rayna",
#     "url": "http://twitter.com/search?q=Rayna",
#     "promoted_content": null,
#     "query": "Rayna",
#     "tweet_volume": null
#    },
#    {
#     "name": "Cameron",
#     "url": "http://twitter.com/search?q=Cameron",
#     "promoted_content": null,
#     "query": "Cameron",
#     "tweet_volume": 20798
#    },
#    {
#     "name": "Lovie Smith",
#     "url": "http://twitter.com/search?q=%22Lovie+Smith%22",
#     "promoted_content": null,
#     "query": "%22Lovie+Smith%22",
#     "tweet_volume": 25054
#    },
#    {
#     "name": "Paolo",
#     "url": "http://twitter.com/search?q=Paolo",
#     "promoted_content": null,
#     "query": "Paolo",
#     "tweet_volume": 12213
#    },
#    {
#     "name": "Roach",
#     "url": "http://twitter.com/search?q=Roach",
#     "promoted_content": null,
#     "query": "Roach",
#     "tweet_volume": null
#    },
#    {
#     "name": "Roberts",
#     "url": "http://twitter.com/search?q=Roberts",
#     "promoted_content": null,
#     "query": "Roberts",
#     "tweet_volume": 30115
#    },
#    {
#     "name": "Duel of the Fates",
#     "url": "http://twitter.com/search?q=%22Duel+of+the+Fates%22",
#     "promoted_content": null,
#     "query": "%22Duel+of+the+Fates%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Javale",
#     "url": "http://twitter.com/search?q=Javale",
#     "promoted_content": null,
#     "query": "Javale",
#     "tweet_volume": null
#    },
#    {
#     "name": "Todrick",
#     "url": "http://twitter.com/search?q=Todrick",
#     "promoted_content": null,
#     "query": "Todrick",
#     "tweet_volume": null
#    },
#    {
#     "name": "Judd",
#     "url": "http://twitter.com/search?q=Judd",
#     "promoted_content": null,
#     "query": "Judd",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hobby Lobby",
#     "url": "http://twitter.com/search?q=%22Hobby+Lobby%22",
#     "promoted_content": null,
#     "query": "%22Hobby+Lobby%22",
#     "tweet_volume": 10124
#    },
#    {
#     "name": "Coach K",
#     "url": "http://twitter.com/search?q=%22Coach+K%22",
#     "promoted_content": null,
#     "query": "%22Coach+K%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Theo John",
#     "url": "http://twitter.com/search?q=%22Theo+John%22",
#     "promoted_content": null,
#     "query": "%22Theo+John%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kihei Clark",
#     "url": "http://twitter.com/search?q=%22Kihei+Clark%22",
#     "promoted_content": null,
#     "query": "%22Kihei+Clark%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Nikki Haley",
#     "url": "http://twitter.com/search?q=%22Nikki+Haley%22",
#     "promoted_content": null,
#     "query": "%22Nikki+Haley%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "The Supreme Court",
#     "url": "http://twitter.com/search?q=%22The+Supreme+Court%22",
#     "promoted_content": null,
#     "query": "%22The+Supreme+Court%22",
#     "tweet_volume": 71088
#    },
#    {
#     "name": "Kurt Zouma",
#     "url": "http://twitter.com/search?q=%22Kurt+Zouma%22",
#     "promoted_content": null,
#     "query": "%22Kurt+Zouma%22",
#     "tweet_volume": 29143
#    },
#    {
#     "name": "Mark Williams",
#     "url": "http://twitter.com/search?q=%22Mark+Williams%22",
#     "promoted_content": null,
#     "query": "%22Mark+Williams%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kyler Murray",
#     "url": "http://twitter.com/search?q=%22Kyler+Murray%22",
#     "promoted_content": null,
#     "query": "%22Kyler+Murray%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "James Carville",
#     "url": "http://twitter.com/search?q=%22James+Carville%22",
#     "promoted_content": null,
#     "query": "%22James+Carville%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kevin Sorbo",
#     "url": "http://twitter.com/search?q=%22Kevin+Sorbo%22",
#     "promoted_content": null,
#     "query": "%22Kevin+Sorbo%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Voting Rights Act",
#     "url": "http://twitter.com/search?q=%22Voting+Rights+Act%22",
#     "promoted_content": null,
#     "query": "%22Voting+Rights+Act%22",
#     "tweet_volume": 28719
#    },
#    {
#     "name": "Azealia Banks",
#     "url": "http://twitter.com/search?q=%22Azealia+Banks%22",
#     "promoted_content": null,
#     "query": "%22Azealia+Banks%22",
#     "tweet_volume": 20717
#    },
#    {
#     "name": "Alpha Academy",
#     "url": "http://twitter.com/search?q=%22Alpha+Academy%22",
#     "promoted_content": null,
#     "query": "%22Alpha+Academy%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Street Profits",
#     "url": "http://twitter.com/search?q=%22Street+Profits%22",
#     "promoted_content": null,
#     "query": "%22Street+Profits%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Eric Bieniemy",
#     "url": "http://twitter.com/search?q=%22Eric+Bieniemy%22",
#     "promoted_content": null,
#     "query": "%22Eric+Bieniemy%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Let's Go Heat",
#     "url": "http://twitter.com/search?q=%22Let%27s+Go+Heat%22",
#     "promoted_content": null,
#     "query": "%22Let%27s+Go+Heat%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Syfy",
#     "url": "http://twitter.com/search?q=Syfy",
#     "promoted_content": null,
#     "query": "Syfy",
#     "tweet_volume": null
#    },
#    {
#     "name": "Keels",
#     "url": "http://twitter.com/search?q=Keels",
#     "promoted_content": null,
#     "query": "Keels",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mitchell Robinson",
#     "url": "http://twitter.com/search?q=%22Mitchell+Robinson%22",
#     "promoted_content": null,
#     "query": "%22Mitchell+Robinson%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "yuzuru hanyu",
#     "url": "http://twitter.com/search?q=%22yuzuru+hanyu%22",
#     "promoted_content": null,
#     "query": "%22yuzuru+hanyu%22",
#     "tweet_volume": 34494
#    },
#    {
#     "name": "Peter Thiel",
#     "url": "http://twitter.com/search?q=%22Peter+Thiel%22",
#     "promoted_content": null,
#     "query": "%22Peter+Thiel%22",
#     "tweet_volume": 19597
#    }
#   ],
#   "as_of": "2022-02-08T02:41:45Z",
#   "created_at": "2022-02-07T02:28:30Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# Now, I am going to search for my favorite hollywood actor and see what twitter is saying about him.
#
# I am doing Leonardo DiCaprio as my hollywood actor.

# %%
#  Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.
import json


#q = "#Ada"
q = '#LeonardoDiCaprio'

count = 1000

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = mathcs_twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = mathcs_twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses, indent=4))
# Out:
# Streaming output truncated to the last 5000 lines.
#                 {
#                     "screen_name": "SensCritique",
#                     "name": "SensCritique",
#                     "id": 41691790,
#                     "id_str": "41691790",
#                     "indices": [
#                         3,
#                         16
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1489643725273903110,
#                     "id_str": "1489643725273903110",
#                     "indices": [
#                         85,
#                         108
#                     ],
#                     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                     "url": "https://t.co/jnj7zvP41t",
#                     "display_url": "pic.twitter.com/jnj7zvP41t",
#                     "expanded_url": "https://twitter.com/SensCritique/status/1489911679299293185/video/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 720,
#                             "h": 588,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 720,
#                             "h": 588,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 555,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1489911679299293185,
#                     "source_status_id_str": "1489911679299293185",
#                     "source_user_id": 41691790,
#                     "source_user_id_str": "41691790"
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1489643725273903110,
#                     "id_str": "1489643725273903110",
#                     "indices": [
#                         85,
#                         108
#                     ],
#                     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                     "url": "https://t.co/jnj7zvP41t",
#                     "display_url": "pic.twitter.com/jnj7zvP41t",
#                     "expanded_url": "https://twitter.com/SensCritique/status/1489911679299293185/video/1",
#                     "type": "video",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 720,
#                             "h": 588,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 720,
#                             "h": 588,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 555,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1489911679299293185,
#                     "source_status_id_str": "1489911679299293185",
#                     "source_user_id": 41691790,
#                     "source_user_id_str": "41691790",
#                     "video_info": {
#                         "aspect_ratio": [
#                             60,
#                             49
#                         ],
#                         "duration_millis": 35834,
#                         "variants": [
#                             {
#                                 "bitrate": 2176000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/vid/720x588/rTKaAw9J0JznjTFV.mp4?tag=12"
#                             },
#                             {
#                                 "bitrate": 832000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/vid/440x360/l_WjcBbOr3KKszQJ.mp4?tag=12"
#                             },
#                             {
#                                 "content_type": "application/x-mpegURL",
#                                 "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/pl/KXfZJfTuz5Z8R-5T.m3u8?tag=12"
#                             },
#                             {
#                                 "bitrate": 256000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/vid/330x270/HtKx4XhwdBINFl_R.mp4?tag=12"
#                             }
#                         ]
#                     },
#                     "additional_media_info": {
#                         "monetizable": false,
#                         "source_user": {
#                             "id": 41691790,
#                             "id_str": "41691790",
#                             "name": "SensCritique",
#                             "screen_name": "SensCritique",
#                             "location": "",
#                             "description": "Le plaisir de la d\u00e9couverte culturelle par le bouche-\u00e0-oreille.",
#                             "url": "https://t.co/YpcmBkfBKC",
#                             "entities": {
#                                 "url": {
#                                     "urls": [
#                                         {
#                                             "url": "https://t.co/YpcmBkfBKC",
#                                             "expanded_url": "http://www.senscritique.com",
#                                             "display_url": "senscritique.com",
#                                             "indices": [
#                                                 0,
#                                                 23
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 "description": {
#                                     "urls": []
#                                 }
#                             },
#                             "protected": false,
#                             "followers_count": 69771,
#                             "friends_count": 1493,
#                             "listed_count": 719,
#                             "created_at": "Thu May 21 22:25:45 +0000 2009",
#                             "favourites_count": 9026,
#                             "utc_offset": null,
#                             "time_zone": null,
#                             "geo_enabled": true,
#                             "verified": true,
#                             "statuses_count": 37175,
#                             "lang": null,
#                             "contributors_enabled": false,
#                             "is_translator": false,
#                             "is_translation_enabled": false,
#                             "profile_background_color": "000000",
#                             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                             "profile_background_tile": false,
#                             "profile_image_url": "http://pbs.twimg.com/profile_images/1327196050751447040/60S2jiKR_normal.jpg",
#                             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1327196050751447040/60S2jiKR_normal.jpg",
#                             "profile_banner_url": "https://pbs.twimg.com/profile_banners/41691790/1641833851",
#                             "profile_link_color": "3B94D9",
#                             "profile_sidebar_border_color": "000000",
#                             "profile_sidebar_fill_color": "000000",
#                             "profile_text_color": "000000",
#                             "profile_use_background_image": false,
#                             "has_extended_profile": false,
#                             "default_profile": false,
#                             "default_profile_image": false,
#                             "following": false,
#                             "follow_request_sent": false,
#                             "notifications": false,
#                             "translator_type": "none",
#                             "withheld_in_countries": []
#                         }
#                     }
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "fr",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 2535486762,
#             "id_str": "2535486762",
#             "name": "Iza S\u00e1rrea",
#             "screen_name": "SarreaIza",
#             "location": "Clichy, France",
#             "description": "Ex #INA #Matignon #CanalPlus #Endemol #S\u00e9nat| Productrice Bim\u00e9dias |Fille de #Thoulouze #Lescure g\u00e9nies de la #TV | #92 | #MeufDeFoot \u26bd\ufe0f\ud83d\udc40| \ud83c\udde9\ud83c\uddff #FemmeDePS",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 680,
#             "friends_count": 1143,
#             "listed_count": 13,
#             "created_at": "Fri May 30 17:07:21 +0000 2014",
#             "favourites_count": 7914,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 14024,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1447580341439500288/cQCv75ar_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1447580341439500288/cQCv75ar_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/2535486762/1643542361",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Sat Feb 05 10:40:00 +0000 2022",
#             "id": 1489911679299293185,
#             "id_str": "1489911679299293185",
#             "text": "Le plus grand fan de #JonahHill : #LeonardoDiCaprio en personne. \ud83d\ude02 https://t.co/jnj7zvP41t",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "JonahHill",
#                         "indices": [
#                             21,
#                             31
#                         ]
#                     },
#                     {
#                         "text": "LeonardoDiCaprio",
#                         "indices": [
#                             34,
#                             51
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1489643725273903110,
#                         "id_str": "1489643725273903110",
#                         "indices": [
#                             67,
#                             90
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                         "url": "https://t.co/jnj7zvP41t",
#                         "display_url": "pic.twitter.com/jnj7zvP41t",
#                         "expanded_url": "https://twitter.com/SensCritique/status/1489911679299293185/video/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 720,
#                                 "h": 588,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 720,
#                                 "h": 588,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 555,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1489643725273903110,
#                         "id_str": "1489643725273903110",
#                         "indices": [
#                             67,
#                             90
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                         "url": "https://t.co/jnj7zvP41t",
#                         "display_url": "pic.twitter.com/jnj7zvP41t",
#                         "expanded_url": "https://twitter.com/SensCritique/status/1489911679299293185/video/1",
#                         "type": "video",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 720,
#                                 "h": 588,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 720,
#                                 "h": 588,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 555,
#                                 "resize": "fit"
#                             }
#                         },
#                         "video_info": {
#                             "aspect_ratio": [
#                                 60,
#                                 49
#                             ],
#                             "duration_millis": 35834,
#                             "variants": [
#                                 {
#                                     "bitrate": 2176000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/vid/720x588/rTKaAw9J0JznjTFV.mp4?tag=12"
#                                 },
#                                 {
#                                     "bitrate": 832000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/vid/440x360/l_WjcBbOr3KKszQJ.mp4?tag=12"
#                                 },
#                                 {
#                                     "content_type": "application/x-mpegURL",
#                                     "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/pl/KXfZJfTuz5Z8R-5T.m3u8?tag=12"
#                                 },
#                                 {
#                                     "bitrate": 256000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/vid/330x270/HtKx4XhwdBINFl_R.mp4?tag=12"
#                                 }
#                             ]
#                         },
#                         "additional_media_info": {
#                             "monetizable": false
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "fr",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 41691790,
#                 "id_str": "41691790",
#                 "name": "SensCritique",
#                 "screen_name": "SensCritique",
#                 "location": "",
#                 "description": "Le plaisir de la d\u00e9couverte culturelle par le bouche-\u00e0-oreille.",
#                 "url": "https://t.co/YpcmBkfBKC",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/YpcmBkfBKC",
#                                 "expanded_url": "http://www.senscritique.com",
#                                 "display_url": "senscritique.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 69771,
#                 "friends_count": 1493,
#                 "listed_count": 719,
#                 "created_at": "Thu May 21 22:25:45 +0000 2009",
#                 "favourites_count": 9026,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": true,
#                 "statuses_count": 37175,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1327196050751447040/60S2jiKR_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1327196050751447040/60S2jiKR_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/41691790/1641833851",
#                 "profile_link_color": "3B94D9",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "has_extended_profile": false,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 47,
#             "favorite_count": 441,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "fr"
#         },
#         "is_quote_status": false,
#         "retweet_count": 47,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "fr"
#     },
#     {
#         "created_at": "Sat Feb 05 13:02:29 +0000 2022",
#         "id": 1489947539390480397,
#         "id_str": "1489947539390480397",
#         "text": "RT @SensCritique: Le plus grand fan de #JonahHill : #LeonardoDiCaprio en personne. \ud83d\ude02 https://t.co/jnj7zvP41t",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "JonahHill",
#                     "indices": [
#                         39,
#                         49
#                     ]
#                 },
#                 {
#                     "text": "LeonardoDiCaprio",
#                     "indices": [
#                         52,
#                         69
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "SensCritique",
#                     "name": "SensCritique",
#                     "id": 41691790,
#                     "id_str": "41691790",
#                     "indices": [
#                         3,
#                         16
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1489643725273903110,
#                     "id_str": "1489643725273903110",
#                     "indices": [
#                         85,
#                         108
#                     ],
#                     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                     "url": "https://t.co/jnj7zvP41t",
#                     "display_url": "pic.twitter.com/jnj7zvP41t",
#                     "expanded_url": "https://twitter.com/SensCritique/status/1489911679299293185/video/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 720,
#                             "h": 588,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 720,
#                             "h": 588,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 555,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1489911679299293185,
#                     "source_status_id_str": "1489911679299293185",
#                     "source_user_id": 41691790,
#                     "source_user_id_str": "41691790"
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1489643725273903110,
#                     "id_str": "1489643725273903110",
#                     "indices": [
#                         85,
#                         108
#                     ],
#                     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                     "url": "https://t.co/jnj7zvP41t",
#                     "display_url": "pic.twitter.com/jnj7zvP41t",
#                     "expanded_url": "https://twitter.com/SensCritique/status/1489911679299293185/video/1",
#                     "type": "video",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 720,
#                             "h": 588,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 720,
#                             "h": 588,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 555,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1489911679299293185,
#                     "source_status_id_str": "1489911679299293185",
#                     "source_user_id": 41691790,
#                     "source_user_id_str": "41691790",
#                     "video_info": {
#                         "aspect_ratio": [
#                             60,
#                             49
#                         ],
#                         "duration_millis": 35834,
#                         "variants": [
#                             {
#                                 "bitrate": 2176000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/vid/720x588/rTKaAw9J0JznjTFV.mp4?tag=12"
#                             },
#                             {
#                                 "bitrate": 832000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/vid/440x360/l_WjcBbOr3KKszQJ.mp4?tag=12"
#                             },
#                             {
#                                 "content_type": "application/x-mpegURL",
#                                 "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/pl/KXfZJfTuz5Z8R-5T.m3u8?tag=12"
#                             },
#                             {
#                                 "bitrate": 256000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/vid/330x270/HtKx4XhwdBINFl_R.mp4?tag=12"
#                             }
#                         ]
#                     },
#                     "additional_media_info": {
#                         "monetizable": false,
#                         "source_user": {
#                             "id": 41691790,
#                             "id_str": "41691790",
#                             "name": "SensCritique",
#                             "screen_name": "SensCritique",
#                             "location": "",
#                             "description": "Le plaisir de la d\u00e9couverte culturelle par le bouche-\u00e0-oreille.",
#                             "url": "https://t.co/YpcmBkfBKC",
#                             "entities": {
#                                 "url": {
#                                     "urls": [
#                                         {
#                                             "url": "https://t.co/YpcmBkfBKC",
#                                             "expanded_url": "http://www.senscritique.com",
#                                             "display_url": "senscritique.com",
#                                             "indices": [
#                                                 0,
#                                                 23
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 "description": {
#                                     "urls": []
#                                 }
#                             },
#                             "protected": false,
#                             "followers_count": 69771,
#                             "friends_count": 1493,
#                             "listed_count": 719,
#                             "created_at": "Thu May 21 22:25:45 +0000 2009",
#                             "favourites_count": 9026,
#                             "utc_offset": null,
#                             "time_zone": null,
#                             "geo_enabled": true,
#                             "verified": true,
#                             "statuses_count": 37175,
#                             "lang": null,
#                             "contributors_enabled": false,
#                             "is_translator": false,
#                             "is_translation_enabled": false,
#                             "profile_background_color": "000000",
#                             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                             "profile_background_tile": false,
#                             "profile_image_url": "http://pbs.twimg.com/profile_images/1327196050751447040/60S2jiKR_normal.jpg",
#                             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1327196050751447040/60S2jiKR_normal.jpg",
#                             "profile_banner_url": "https://pbs.twimg.com/profile_banners/41691790/1641833851",
#                             "profile_link_color": "3B94D9",
#                             "profile_sidebar_border_color": "000000",
#                             "profile_sidebar_fill_color": "000000",
#                             "profile_text_color": "000000",
#                             "profile_use_background_image": false,
#                             "has_extended_profile": false,
#                             "default_profile": false,
#                             "default_profile_image": false,
#                             "following": false,
#                             "follow_request_sent": false,
#                             "notifications": false,
#                             "translator_type": "none",
#                             "withheld_in_countries": []
#                         }
#                     }
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "fr",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1360020812,
#             "id_str": "1360020812",
#             "name": "bibabou",
#             "screen_name": "bibabou2",
#             "location": "",
#             "description": "",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 7,
#             "friends_count": 294,
#             "listed_count": 0,
#             "created_at": "Wed Apr 17 18:01:18 +0000 2013",
#             "favourites_count": 1411,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 1211,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/837537964439658499/wz2thQaj_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/837537964439658499/wz2thQaj_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1360020812/1488519585",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Sat Feb 05 10:40:00 +0000 2022",
#             "id": 1489911679299293185,
#             "id_str": "1489911679299293185",
#             "text": "Le plus grand fan de #JonahHill : #LeonardoDiCaprio en personne. \ud83d\ude02 https://t.co/jnj7zvP41t",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "JonahHill",
#                         "indices": [
#                             21,
#                             31
#                         ]
#                     },
#                     {
#                         "text": "LeonardoDiCaprio",
#                         "indices": [
#                             34,
#                             51
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1489643725273903110,
#                         "id_str": "1489643725273903110",
#                         "indices": [
#                             67,
#                             90
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                         "url": "https://t.co/jnj7zvP41t",
#                         "display_url": "pic.twitter.com/jnj7zvP41t",
#                         "expanded_url": "https://twitter.com/SensCritique/status/1489911679299293185/video/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 720,
#                                 "h": 588,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 720,
#                                 "h": 588,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 555,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1489643725273903110,
#                         "id_str": "1489643725273903110",
#                         "indices": [
#                             67,
#                             90
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                         "url": "https://t.co/jnj7zvP41t",
#                         "display_url": "pic.twitter.com/jnj7zvP41t",
#                         "expanded_url": "https://twitter.com/SensCritique/status/1489911679299293185/video/1",
#                         "type": "video",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 720,
#                                 "h": 588,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 720,
#                                 "h": 588,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 555,
#                                 "resize": "fit"
#                             }
#                         },
#                         "video_info": {
#                             "aspect_ratio": [
#                                 60,
#                                 49
#                             ],
#                             "duration_millis": 35834,
#                             "variants": [
#                                 {
#                                     "bitrate": 2176000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/vid/720x588/rTKaAw9J0JznjTFV.mp4?tag=12"
#                                 },
#                                 {
#                                     "bitrate": 832000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/vid/440x360/l_WjcBbOr3KKszQJ.mp4?tag=12"
#                                 },
#                                 {
#                                     "content_type": "application/x-mpegURL",
#                                     "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/pl/KXfZJfTuz5Z8R-5T.m3u8?tag=12"
#                                 },
#                                 {
#                                     "bitrate": 256000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/vid/330x270/HtKx4XhwdBINFl_R.mp4?tag=12"
#                                 }
#                             ]
#                         },
#                         "additional_media_info": {
#                             "monetizable": false
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "fr",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 41691790,
#                 "id_str": "41691790",
#                 "name": "SensCritique",
#                 "screen_name": "SensCritique",
#                 "location": "",
#                 "description": "Le plaisir de la d\u00e9couverte culturelle par le bouche-\u00e0-oreille.",
#                 "url": "https://t.co/YpcmBkfBKC",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/YpcmBkfBKC",
#                                 "expanded_url": "http://www.senscritique.com",
#                                 "display_url": "senscritique.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 69771,
#                 "friends_count": 1493,
#                 "listed_count": 719,
#                 "created_at": "Thu May 21 22:25:45 +0000 2009",
#                 "favourites_count": 9026,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": true,
#                 "statuses_count": 37175,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1327196050751447040/60S2jiKR_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1327196050751447040/60S2jiKR_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/41691790/1641833851",
#                 "profile_link_color": "3B94D9",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "has_extended_profile": false,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 47,
#             "favorite_count": 441,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "fr"
#         },
#         "is_quote_status": false,
#         "retweet_count": 47,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "fr"
#     },
#     {
#         "created_at": "Sat Feb 05 12:40:21 +0000 2022",
#         "id": 1489941967454846980,
#         "id_str": "1489941967454846980",
#         "text": "RT @SensCritique: Le plus grand fan de #JonahHill : #LeonardoDiCaprio en personne. \ud83d\ude02 https://t.co/jnj7zvP41t",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "JonahHill",
#                     "indices": [
#                         39,
#                         49
#                     ]
#                 },
#                 {
#                     "text": "LeonardoDiCaprio",
#                     "indices": [
#                         52,
#                         69
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "SensCritique",
#                     "name": "SensCritique",
#                     "id": 41691790,
#                     "id_str": "41691790",
#                     "indices": [
#                         3,
#                         16
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1489643725273903110,
#                     "id_str": "1489643725273903110",
#                     "indices": [
#                         85,
#                         108
#                     ],
#                     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                     "url": "https://t.co/jnj7zvP41t",
#                     "display_url": "pic.twitter.com/jnj7zvP41t",
#                     "expanded_url": "https://twitter.com/SensCritique/status/1489911679299293185/video/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 720,
#                             "h": 588,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 720,
#                             "h": 588,
#                             "resize": "fit"
#                         },
#                         "small": {
# ...
#                         ]
#                     },
#                     {
#                         "text": "LeonardoDiCaprio",
#                         "indices": [
#                             34,
#                             51
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1489643725273903110,
#                         "id_str": "1489643725273903110",
#                         "indices": [
#                             67,
#                             90
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                         "url": "https://t.co/jnj7zvP41t",
#                         "display_url": "pic.twitter.com/jnj7zvP41t",
#                         "expanded_url": "https://twitter.com/SensCritique/status/1489911679299293185/video/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 720,
#                                 "h": 588,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 720,
#                                 "h": 588,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 555,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1489643725273903110,
#                         "id_str": "1489643725273903110",
#                         "indices": [
#                             67,
#                             90
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1489643725273903110/pu/img/jediqHM8Oc-T9-Az.jpg",
#                         "url": "https://t.co/jnj7zvP41t",
#                         "display_url": "pic.twitter.com/jnj7zvP41t",
#                         "expanded_url": "https://twitter.com/SensCritique/status/1489911679299293185/video/1",
#                         "type": "video",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 720,
#                                 "h": 588,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 720,
#                                 "h": 588,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 555,
#                                 "resize": "fit"
#                             }
#                         },
#                         "video_info": {
#                             "aspect_ratio": [
#                                 60,
#                                 49
#                             ],
#                             "duration_millis": 35834,
#                             "variants": [
#                                 {
#                                     "bitrate": 2176000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/vid/720x588/rTKaAw9J0JznjTFV.mp4?tag=12"
#                                 },
#                                 {
#                                     "bitrate": 832000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/vid/440x360/l_WjcBbOr3KKszQJ.mp4?tag=12"
#                                 },
#                                 {
#                                     "content_type": "application/x-mpegURL",
#                                     "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/pl/KXfZJfTuz5Z8R-5T.m3u8?tag=12"
#                                 },
#                                 {
#                                     "bitrate": 256000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1489643725273903110/pu/vid/330x270/HtKx4XhwdBINFl_R.mp4?tag=12"
#                                 }
#                             ]
#                         },
#                         "additional_media_info": {
#                             "monetizable": false
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "fr",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 41691790,
#                 "id_str": "41691790",
#                 "name": "SensCritique",
#                 "screen_name": "SensCritique",
#                 "location": "",
#                 "description": "Le plaisir de la d\u00e9couverte culturelle par le bouche-\u00e0-oreille.",
#                 "url": "https://t.co/YpcmBkfBKC",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/YpcmBkfBKC",
#                                 "expanded_url": "http://www.senscritique.com",
#                                 "display_url": "senscritique.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 69771,
#                 "friends_count": 1493,
#                 "listed_count": 719,
#                 "created_at": "Thu May 21 22:25:45 +0000 2009",
#                 "favourites_count": 9026,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": true,
#                 "statuses_count": 37175,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1327196050751447040/60S2jiKR_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1327196050751447040/60S2jiKR_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/41691790/1641833851",
#                 "profile_link_color": "3B94D9",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "has_extended_profile": false,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 47,
#             "favorite_count": 441,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "fr"
#         },
#         "is_quote_status": false,
#         "retweet_count": 47,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "fr"
#     },
#     {
#         "created_at": "Sat Feb 05 11:00:14 +0000 2022",
#         "id": 1489916773302427653,
#         "id_str": "1489916773302427653",
#         "text": "#adrianbrody #thepianist #movie #movies #romanpolanski #predators #actor #joker #piano #leonardodicaprio #fury\u2026 https://t.co/GVCYvcbfGV",
#         "truncated": true,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "adrianbrody",
#                     "indices": [
#                         0,
#                         12
#                     ]
#                 },
#                 {
#                     "text": "thepianist",
#                     "indices": [
#                         13,
#                         24
#                     ]
#                 },
#                 {
#                     "text": "movie",
#                     "indices": [
#                         25,
#                         31
#                     ]
#                 },
#                 {
#                     "text": "movies",
#                     "indices": [
#                         32,
#                         39
#                     ]
#                 },
#                 {
#                     "text": "romanpolanski",
#                     "indices": [
#                         40,
#                         54
#                     ]
#                 },
#                 {
#                     "text": "predators",
#                     "indices": [
#                         55,
#                         65
#                     ]
#                 },
#                 {
#                     "text": "actor",
#                     "indices": [
#                         66,
#                         72
#                     ]
#                 },
#                 {
#                     "text": "joker",
#                     "indices": [
#                         73,
#                         79
#                     ]
#                 },
#                 {
#                     "text": "piano",
#                     "indices": [
#                         80,
#                         86
#                     ]
#                 },
#                 {
#                     "text": "leonardodicaprio",
#                     "indices": [
#                         87,
#                         104
#                     ]
#                 },
#                 {
#                     "text": "fury",
#                     "indices": [
#                         105,
#                         110
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/GVCYvcbfGV",
#                     "expanded_url": "https://twitter.com/i/web/status/1489916773302427653",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         112,
#                         135
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "und",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://publer.io\" rel=\"nofollow\">Publer.io</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1220155527545675776,
#             "id_str": "1220155527545675776",
#             "name": "L'actu cin\u00e9, s\u00e9rie et manga vu depuis #lareunion",
#             "screen_name": "cinemanga974",
#             "location": "La R\u00e9union",
#             "description": "Cinemanga974 l'actualit\u00e9 du cin\u00e9ma, des mangas et des s\u00e9ries TV vu depuis La R\u00e9union par sa communaut\u00e9s de fans. Suivez nous aussi sur Facebook et Instagram.",
#             "url": "https://t.co/rGQf865qQt",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/rGQf865qQt",
#                             "expanded_url": "https://www.facebook.com/Cinemanga974/",
#                             "display_url": "facebook.com/Cinemanga974/",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 88,
#             "friends_count": 746,
#             "listed_count": 3,
#             "created_at": "Thu Jan 23 01:25:46 +0000 2020",
#             "favourites_count": 2,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 1291,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1247144786945019906/tPhVpYTK_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1247144786945019906/tPhVpYTK_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "und"
#     }
# ]
