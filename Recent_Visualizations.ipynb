# %% [markdown]
# <a href="https://colab.research.google.com/github/bbishal12/Quiz0/blob/main/Recent_Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unemployment Rate Visualization

# %% [markdown]
# Bishal Budhathoki
#
# East Central University
#
# Spring 2022
#
# CPSMA 4313
#
# Project: Recent Visualizations

# %% [markdown]
# The unemployment rate is the percentage of unemployed workers in the labor force. It's a key indicator of the health of the country's economy. Unemployment typically rises during recessions and falls during periods of economic prosperity. The rate also declined during several U.S. wars, particularly during World War II. The unemployment rate rose during the recessions that followed those wars.
#
# We will examine these news reports to see how they use visualizations to discuss this important indicator.

# %% [markdown]
# #Daily Mail
#
# ![](https://i.dailymail.co.uk/1s/2022/03/21/19/55624537-10636861-image-a-13_1647892483312.jpg)

# %% [markdown]
# The above image was taken from [DailyMail.com]( https://www.dailymail.co.uk/news/article-10636861/NYC-7-5-unemployment-rate-dependent-office-workers-refuse-return.html) on March 21st 2022.
#
# The visualization we will examine is the Unemployment rate of the NYC using histogram graph. We can still examine it for graphical excellence.
#
# The source of this page is Daily Mail.com. The daily mail is the online breaking news where we can get latest news, celebrity photos, viral videos and many more news. As we can see the graph is clearly a bar graph which is very easy to understand and clear. The whole bar graph is dark blue on the background whereas the the bar graph is light blue. The heading is NYC unemployment rockets whereas on the x-axis its millions dollar and on the y-axis is the date starting February 2020 to December 2021. So, the graph is a time verus dollars. As from the April 2020 the pay check was decreased a lot because many people were unemployment due to pandemic and COVID-19.
#
# Overall the graph is an excellent graphic. Althoufh the bar graph looks incomplete because it only compare with 3 months. Also, they didnot highlight the lower pay check month which was April 2020.

# %% [markdown]
# #CNN
#
# ![Capture2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Next article we going to examine is from [CNN](https://www.cnn.com/2022/04/01/economy/us-march-jobs-report/index.html) taken on April 1st 2022. CNN provides live coverage breaking news as well as a full range of international, political, business and many more. We can see a good picture of the graph visualization on this website.
#
# We will look at this visualization where CNN says the unempolyment rate to a new pandemic low. From the screenshot image we can see a bar graph where the title is Jobs Past year. The bar graph color is red highlighted and the graph is time verus money. On the y-axis we can see the dollars and on the x-axis we can see month. When we compare this article with the above one this article trying a say that US unemployment rate has been decrease and better than pandemic low.
#
# Overall I think this is a good graphic. Although this graph doesnot have data like year to year compare to above article. This graph actually telling that the umemplolyment rate has been decreased and bringing jobless rate to pandemic low.

# %% [markdown]
# #Reuters
#
# ![](https://graphics.reuters.com/USA-STOCKS/movanbdwmpa/nfpr.png)

# %% [markdown]
# Another article we will examine is from [Reuters](https://www.reuters.com/world/us/us-job-growth-solid-march-unemployment-rate-falls-36-2022-04-01/) taken on March 1st 2022. Reuters is the breaking news online channel which provides business, financial, national and international news.
#
# The image of this website graph is bar graph just like the above articles graph.
# This graph is interesting as we can see the almost every month of 2021 but this graph is after pandemic which is after 2020. As we can see two different graph in this article because this article is about that the unemployment rate is decreased and nonfarm payrolls increased in March.
#
# Even though this graph looks different than two other graphs it is clear and understandable. Also, if we check the article of this graph visual there are some clear describing given than other two graphs which helps to get more ideas about graphs and its data. This graph is also time versus amount. On the x-axis we can see the time whereas on the y-axis there is payrolls amount. The bar graph is highlighted in orange color and the heading is US non-farm payrolls.
#
# Overall I think this is a good graphic. Eventhough this graph is all about after pandemic year. So, we cant say the unemployment rate is changed a lot. But according to article, the US unemployment rate is decreasing and non-farm payrolls increased.

# %% [markdown]
# #References:
#
# https://www.thebalance.com/unemployment-rate-by-year-3305506
#
# https://www.dailymail.co.uk/news/article-10636861/NYC-7-5-unemployment-rate-dependent-office-workers-refuse-return.html
#
# https://www.reuters.com/world/us/us-job-growth-solid-march-unemployment-rate-falls-36-2022-04-01/
