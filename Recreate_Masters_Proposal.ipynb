# %% [markdown]
# <a href="https://colab.research.google.com/github/bbishal12/Quiz0/blob/main/Recreate_Masters_Proposal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bishal Budhathoki
#
# East Central University
#
# Spring 2022
#
# CPSMA 4313
#
# Recreate Masters Proposal

# %% [markdown]
# #[THE ENGLISH PREMIER LEAGUE](https://public.tableau.com/app/profile/bo.mccready8742/viz/PremierLeagueTeams20-21VisualHistory/Histories)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# My recreate masters project will be the Premier League Teams 2020-2021. I will be using the yield curve graph to recreate the masters. The below is the link for my recreate masters.
# https://public.tableau.com/app/profile/bo.mccready8742/viz/PremierLeagueTeams20-21VisualHistory/Histories
#
# The dataset link for the above graph is:
# https://github.com/bbishal12/Quiz0/blob/main/1st%2010_data.csv
#
# In this graph each club comapares the promoted to higher division and relegated to lower division. There are 3 labels where up arrow, down arrow and circle. Each has their own meaning. The graph has x-axis and y-axis where on the x-axis we can see the time in years and on the y-axis the name of the club.
#
# The website graph is a yield curve inverts graph as I am going to recreate the graph in an accurate and excellence display. This graph is an good excellence graph. There are 3 label where arrow up means that promoted to higher divison , arrow down means relegated to lower division and circle means club with top division champions. Eventhough this graph looks little complicated as each club memebers have separate curve inverted graph with the year on the y-axis. We can recreate this graph by selecting one club at the time. There will a lot of hardship while I am trying to recreate its master. The web version graph is complicated and my hardship is to separate the each club with the relegated and promoted division.
