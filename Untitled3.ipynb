# %% [markdown]
# <a href="https://colab.research.google.com/github/bbishal12/Quiz0/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Visualization
# ##Bishal Budhathoki
# ##Quiz 4 : SQL Essential

# %% [markdown]
# Use the Cloud Resource Manager to Create a Cloud Platform project if you do not already have one.
# Enable billing for the project.
# Enable BigQuery APIs for the project.

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# Now that we are authenticated. We are going to look at the bikers trip data from Austin. We have a project called data-viz-bishal in my BigQuery interface

# %% [markdown]
# 1. Navigate to the dataset 'austin_bikeshare.bikeshare_trips'

# %%
# %%bigquery --project data-viz-bishal
# SELECT
#   COUNT(*) as total_rows
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# Out:
#    total_rows
# 0     1424786

# %% [markdown]
# Here is the dataset of austin_bikeshare.bikeshre_trips

# %% [markdown]
# Computing the no of entries in the dataset.

# %%
# %%bigquery --project data-viz-bishal
# SELECT
#   COUNT(*) as total_entries
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# Out:
#    total_entries
# 0        1424786

# %% [markdown]
# That is big entries.
# There is alot of entries in the data set excel will have hard time computing. SQL do the data manipulations on the database server.

# %% [markdown]
# Compute the average time for a trip based on starting point

# %%
# %%bigquery --project data-viz-bishal
# SELECT
#   start_station_name,
#   AVG(duration_minutes) as Average_time_for_trip
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# WHERE start_station_name is not null
# GROUP BY start_station_name
# Out:
#                         start_station_name  Average_time_for_trip
# 0                         Zilker Park West              27.168259
# 1                  Toomey Rd @ South Lamar              28.115798
# 2          State Capitol @ 14th & Colorado              30.421842
# 3                         Waller & 6th St.              23.265843
# 4                               Pease Park              28.648889
# ..                                     ...                    ...
# 188  Republic Square @ Guadalupe & 4th St.              23.067313
# 189                             3rd & West              19.937466
# 190                               3rd/West              34.152547
# 191                          Nueces & 26th              16.805353
# 192                            26th/Nueces              24.521670
#
# [193 rows x 2 columns]

# %% [markdown]
# There are 13967 rows in the above data. Those are the average time for every indiviual trip.

# %% [markdown]
# Computing the average time for a trip based on starting point

# %%
# %%bigquery --project data-viz-bishal
# SELECT
#   start_station_name,
#   AVG(duration_minutes) as Average_time_for_trip
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# WHERE start_station_name is not null
# GROUP BY start_station_name
# Out:
#                         start_station_name  Average_time_for_trip
# 0                         Zilker Park West              27.168259
# 1                  Toomey Rd @ South Lamar              28.115798
# 2          State Capitol @ 14th & Colorado              30.421842
# 3                         Waller & 6th St.              23.265843
# 4                               Pease Park              28.648889
# ..                                     ...                    ...
# 188  Republic Square @ Guadalupe & 4th St.              23.067313
# 189                             3rd & West              19.937466
# 190                               3rd/West              34.152547
# 191                          Nueces & 26th              16.805353
# 192                            26th/Nueces              24.521670
#
# [193 rows x 2 columns]

# %% [markdown]
# Here, in the dataset is the trips start at each starting point (name).
